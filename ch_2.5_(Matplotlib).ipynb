# %% [markdown]
# # Matplotlib 기초

# %% [markdown]
# ## 1. Matplotlib 이란?

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.figure.max_open_warning = False

# %matplotlib notebook 
#%matplotlib inline

#위와 같은 것이 %로 시작하는 것을 jupyter notebook의 magic command라고 한다.
# %who는 변수명의 리스트를 보여주고 %magic 은 모든 매직명령어를 보여준다.

# 전체적인 magic 명령어에 대해서는 다음 블로그를 참고
# http://studymake.tistory.com/601
# matplotlib 을 jupyter notebook에서 사용할 때, plot의 이미지를 보여주기 위해 magic command를 사용하는데,
# 이때 우리가 사용하는 nbagg 이외에도 다음과 같은 요소를 사용할 수 있다.
# Available matplotlib backends: ['osx', 'qt4', 'qt5', 'gtk3', 'notebook', 'wx', 'qt', 'nbagg','gtk', 'tk', 'inline']

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Plot의 종류
# ### 2-1 Line plot 그리기

# %%
# Series를 통한 line plot 그리기
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s
# Out:
# 0    -0.386868
# 10    1.281316
# 20    1.766670
# 30    1.205010
# 40    2.874979
# 50    3.975453
# 60    2.067731
# 70    1.709880
# 80    1.772440
# 90    0.587421
# dtype: float64

# %%
# 위에서 정의한 s라는 시리즈에 대해서 line plot을 그리고 싶다면?
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - s 라는 Series에서의 index와 value를 통해 그래프가 그려졌다.
# - 그래프 상단의 전원버튼을 누르기 전까지 우리는 해당 그래프를 interactive하게 조작할 수 있다.

# %%
# DataFrame을 통한 line plot 그리기
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   0.804829  0.588057 -1.092658 -1.368475
# 10 -0.199017  2.085821 -2.124019 -3.023152
# 20  0.972363  2.632495 -2.139273 -3.634158
# 30  2.813946  2.720609 -3.126300 -3.684469
# 40  2.880259  3.408905 -3.216323 -4.082483
# 50  3.341717  4.061333 -5.782365 -6.137923
# 60  3.796291  3.084734 -5.200536 -8.982260
# 70  4.743215  2.145581 -4.139332 -8.310723
# 80  2.896368  1.321888 -5.894181 -8.792576
# 90  3.477333  2.507379 -6.354616 -8.954094

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close('all')
# 하나의 열에 대해서만 보고 싶다면?
df['B'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 2-2 Bar plot 그리기

# %%
plt.close('all')
s2 = pd.DataFrame(np.random.rand(16), index=list("abcdefghijklmnop"))

# %%
s2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 가로방향의 bar plot그리기
s2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df2
# Out:
# Genus         A         B         C         D
# one    0.170379  0.144450  0.045057  0.283341
# two    0.983996  0.111009  0.864649  0.844660
# three  0.521577  0.532970  0.783959  0.622976
# four   0.526669  0.808643  0.549464  0.008550
# five   0.195867  0.742070  0.798155  0.740979
# six    0.604120  0.572722  0.236118  0.981792

# %%
df2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 위와 같이 Stacked 속성을 True로 설정하면, 하나의 인덱스에 대한 각 열의 값을 한줄로 쌓아서 나타내준다.

# %% [markdown]
# ### 2-3 Histogram 그리기
# - histogram은 index가 필요없다.

# %%
plt.close('all')
s3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
s3.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# x 축의 구간 개수를 bin이라고 한다.
#
# 이를 직접 설정할 수도 있다.

# %%
plt.close('all')
s3.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close('all')
s3.hist(bins=100, density=True)
# normed 속성을 True로 설정하면, 각 bin에 속하는 개수를 전체 개수로 나눈 비율, 즉 정규화 한 값을 bar의 높이로 사용하게 된다.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 산점도(Scatter plot) 그리기
# 산점도의 경우에는 서로 다른 두 개의 독립변수에 대해 두 변수가 어떤 관계가 있는지 살펴보기 위해 사용된다.

# %%
plt.close('all')
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis=1)

# %%
df3 = pd.DataFrame(X, columns=["x1", "x2"])
df3
# Out:
#           x1        x2
# 0   0.632946  0.523379
# 1  -0.039774 -1.679426
# 2   1.953593  1.056012
# 3  -0.048100 -7.598126
# 4   0.973518  1.800171
# ..       ...       ...
# 95  0.283096  9.207727
# 96  1.550076 -2.256530
# 97  1.559306  2.749163
# 98  1.352860 -8.582143
# 99  0.749315 -1.358178
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2']) # x1이 x축, x2가 y축
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 3. Plot 모양 변형하기

# %% [markdown]
# ### 3-1 서브 플롯 그리기

# %%
plt.close('all')
fig = plt.figure()
# 비어있는 figure가 생성된다.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# subplot 추가하기, add_subplot 에는 총 3가지 인자가 들어간다.

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %% [markdown]
# - 첫번째 숫자와 두번째 숫자 : 우리가 figure를 어떤 크기로 나눌지에 대한 값이다. 즉 위의 같은 경우는 2,2 이므로 우리의 figure를 2x2로 나눈다는 뜻.
# - 세번째 숫자 : 첫번째, 두번째 숫자로 나눈 figure에서 좌측상단으로 우측방향으로 숫자가 붙는다. 이때 우리가 add하고자 하는 subplot이 몇번째에 들어가는지를 나타낸다.
# - 즉, 위와 같은 경우 figure는 다음과 같이 나누어진다.
# - 1  2
# - 3  4
# - 이때 우리는 1위치에 subplot을 추가하고 해당 subplot을 ax1이라는 변수로 반환받는다.

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum())
# 위치를 지정하지 않고 plot을 그리니 맨마지막에 그림이 그려진다.
# figure에 추가된 subplot상 맨 마지막에 위치한 곳에 그려지는 것이 아니라, 제일 마지막에 추가한 subplot에 그려진다.
# 2 -> 3 -> 1 순으로 subplot을 추가하여 테스트 해보면 1번 요소에 그려진다.

# %%
plt.plot(np.random.randn(200).cumsum())
# 강의에서는 한번더 위치 지정 없이 그리면 그 전의 요소에 그려진다고 했는데,
# 실제로 진행해보면 그냥 위의 것과 똑같이 제일 마지막에 추가한 subplot에 중복되서 그려진다.

# %%
# 그럼 우리가 원하는 위치에 그림을 그리기 위해서는?
# 위에서 add_subplot 을 할때 변수명을 지정하여 반환값을 받았다.
# 해당 변수를 통해 plot을 그리면 된다.
ax1.hist(np.random.randn(100), bins = 20) # bins는 x축 bar의 개수
# Out:
# (array([ 1.,  0.,  0.,  1.,  2.,  2.,  5.,  7.,  2.,  9., 18.,  9., 12.,
#         15.,  6.,  5.,  2.,  0.,  2.,  2.]),
#  array([-3.35154742, -3.0502501 , -2.74895279, -2.44765547, -2.14635816,
#         -1.84506085, -1.54376353, -1.24246622, -0.9411689 , -0.63987159,
#         -0.33857427, -0.03727696,  0.26402036,  0.56531767,  0.86661499,
#          1.1679123 ,  1.46920962,  1.77050693,  2.07180425,  2.37310156,
#          2.67439888]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %% [markdown]
# #### 서브플롯의 다른 정의 방법

# %%
fig, axes = plt.subplots(2,3)
# 위와 같이 만들면 2x3 subplot들을 가지는 figure를 만드는 것
# 이때 반환되는 값은 2개로써, figrue 자체와, 축
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 반환받은 axes에는 우리가 위에서 설정한 크기와 같은 shape의 리스트로 각 요소에는 subplot 객체가 들어있다.
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002899F7020D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002899F7330A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002899F7611F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002899F784100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002899F7BE400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002899F7E88E0>]],
#       dtype=object)

# %% [markdown]
# #### 서브플롯 간 간격 조절하기

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
        
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 3-2. Plot 꾸미기

# %%
plt.close()
# 지금까지의 Plot
plt.figure()
plt.plot(np.random.randn(30))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 마커 및 라인 스타일 수정
# ##### color : 값 색상
#     - "b" blue
#     - "g" green
#     - "r" red
#     - "c" cyan
#     - "m" magenta
#     - "y" yellow
#     - "k" black
#     - "w" white
#
# ##### marker : 값 마킹
#     - "." point
#     - "," pixel
#     - "o" circle
#     - "v" triangle_down
#     - "^" triangle_up
#     - "<" triangle_left
#     - ">" triangle_right
#     - "8" octagon
#     - "s" square
#     - "p" pentagon
#     - "*" star
#     - "h" hexagon
#     - "+" plus
#     - "x" x
#     - "D" diamond
#
# ##### line style : 값 라인 스타일
#     - "-" solid line
#     - "--" dashed line
#     - "-." dash-dotted line
#     - ":" dotted line
#     - "None" draw nothing

# %%
plt.close('all')

plt.figure()
plt.plot(np.random.randn(50), color = 'g', marker='o', linestyle='--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7) #plot 함수를 그릴때, figure에서 원하는 위치를 지정하기 위해 ax 속성을 사용

# %%
data.plot(kind='barh', ax=axes[1], color='g', alpha=0.3)

# %% [markdown]
# #### plot의 제목, 눈금, 레이블 수정

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())

# %%
# 이때 그래프에서 나타내는 눈금을 tick이라고 한다.
# 즉, 위의 그래프의 x tick은 200이고 y tick은 10이다.
ax.set_xticks([0, 250, 500, 750, 1000])
# Out:
# [<matplotlib.axis.XTick at 0x289a195ec10>,
#  <matplotlib.axis.XTick at 0x289a195ebe0>,
#  <matplotlib.axis.XTick at 0x289a190ebb0>,
#  <matplotlib.axis.XTick at 0x289a1c0c040>,
#  <matplotlib.axis.XTick at 0x289a1c0c550>]

# %%
# 제목 입력하기
ax.set_title('random walk plot')
# Out:
# Text(0.5, 1.0, 'random walk plot')

# %%
# 라벨 입력하기
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
# Out:
# Text(44.222222222222214, 0.5, 'Values')

# %%
# 눈금을 문자로 하기 위해서는?
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation = 30, fontsize='small')

# %% [markdown]
# #### 범례, 축 범위 수정

# %%
plt.close('all')
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'b--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')

# %%
# 범례 표시하기
ax.legend(loc='best')
# loc는 범례가 위치할 곳을 의미한다. best를 주게 되면 현재 그래프에서 최적의 위치를 자동으로 찾는다.

# %%
ax.get_xlim()
# 현재 그래프의 x축 범위를 가져온다.
# Out:
# (-49.95, 1048.95)

# %%
# 이를 변경하려면,
ax.set_xlim([100,900])
# Out:
# (100.0, 900.0)

# %%
ax.set_ylim([-100,100])
# Out:
# (-100.0, 100.0)

# %% [markdown]
# ## 4. Matplotlib을 이용한 데이터시각화 맛보기

# %%
battles = pd.read_csv('game-of-thrones/battles.csv', sep=',')
deaths = pd.read_csv('game-of-thrones/character-deaths.csv', sep=',')
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# 1        NaN        NaN  Baratheon  ...         1.0            0.0
# 2        NaN        NaN      Tully  ...         0.0            1.0
# 3        NaN        NaN  Lannister  ...         1.0            1.0
# 4        NaN        NaN  Lannister  ...         1.0            1.0
#
#    attacker_size defender_size  \
# 0        15000.0        4000.0
# 1            NaN         120.0
# 2        15000.0       10000.0
# 3        18000.0       20000.0
# 4         1875.0        6000.0
#
#                                   attacker_commander  \
# 0                                    Jaime Lannister
# 1                                     Gregor Clegane
# 2                       Jaime Lannister, Andros Brax
# 3  Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# 4                          Robb Stark, Brynden Tully
#
#                                   defender_commander  summer         location  \
# 0                               Clement Piper, Vance     1.0     Golden Tooth
# 1                                   Beric Dondarrion     1.0    Mummer's Ford
# 2                      Edmure Tully, Tytos Blackwood     1.0         Riverrun
# 3  Tywin Lannister, Gregor Clegane, Kevan Lannist...     1.0       Green Fork
# 4                                    Jaime Lannister     1.0  Whispering Wood
#
#             region note
# 0  The Westerlands  NaN
# 1   The Riverlands  NaN
# 2   The Riverlands  NaN
# 3   The Riverlands  NaN
# 4   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battles.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
battles.shape
# Out:
# (38, 25)

# %%
deaths.shape
# Out:
# (917, 13)

# %%
deaths.columns
# Out:
# Index(['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
deaths.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
book_nums_to_death_count = deaths['Book of Death'].value_counts().sort_index()
book_nums_to_death_count
# Out:
# 1.0    49
# 2.0    73
# 3.0    97
# 4.0    27
# 5.0    61
# Name: Book of Death, dtype: int64

# %%
ax1 = book_nums_to_death_count.plot(color = 'k', marker='o', linestyle='--')

# 모양 가다듬기
ax1.set_xticks(np.arange(1,6))
# Out:
# [<matplotlib.axis.XTick at 0x289a1c3ec70>,
#  <matplotlib.axis.XTick at 0x289a1c3ec40>,
#  <matplotlib.axis.XTick at 0x289a1948eb0>,
#  <matplotlib.axis.XTick at 0x289a161d580>,
#  <matplotlib.axis.XTick at 0x289a161da90>]

# %%
ax1.set_xlim([0,6])
ax1.set_ylim([0,120])
# Out:
# (0.0, 120.0)

# %%
battles = battles.set_index(['name'])
battles.head()
# Out:
#                                year  battle_number             attacker_king  \
# name
# Battle of the Golden Tooth      298              1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford     298              2  Joffrey/Tommen Baratheon
# Battle of Riverrun              298              3  Joffrey/Tommen Baratheon
# Battle of the Green Fork        298              4                Robb Stark
# Battle of the Whispering Wood   298              5                Robb Stark
#
#                                           defender_king attacker_1 attacker_2  \
# name
# Battle of the Golden Tooth                   Robb Stark  Lannister        NaN
# Battle at the Mummer's Ford                  Robb Stark  Lannister        NaN
# Battle of Riverrun                           Robb Stark  Lannister        NaN
# Battle of the Green Fork       Joffrey/Tommen Baratheon      Stark        NaN
# Battle of the Whispering Wood  Joffrey/Tommen Baratheon      Stark      Tully
#
#                               attacker_3 attacker_4 defender_1 defender_2  \
# name
# Battle of the Golden Tooth           NaN        NaN      Tully        NaN
# Battle at the Mummer's Ford          NaN        NaN  Baratheon        NaN
# Battle of Riverrun                   NaN        NaN      Tully        NaN
# Battle of the Green Fork             NaN        NaN  Lannister        NaN
# Battle of the Whispering Wood        NaN        NaN  Lannister        NaN
#
#                                ...  major_death  major_capture attacker_size  \
# name                           ...
# Battle of the Golden Tooth     ...          1.0            0.0       15000.0
# Battle at the Mummer's Ford    ...          1.0            0.0           NaN
# Battle of Riverrun             ...          0.0            1.0       15000.0
# Battle of the Green Fork       ...          1.0            1.0       18000.0
# Battle of the Whispering Wood  ...          1.0            1.0        1875.0
#
#                               defender_size  \
# name
# Battle of the Golden Tooth           4000.0
# Battle at the Mummer's Ford           120.0
# Battle of Riverrun                  10000.0
# Battle of the Green Fork            20000.0
# Battle of the Whispering Wood        6000.0
#
#                                                               attacker_commander  \
# name
# Battle of the Golden Tooth                                       Jaime Lannister
# Battle at the Mummer's Ford                                       Gregor Clegane
# Battle of Riverrun                                  Jaime Lannister, Andros Brax
# Battle of the Green Fork       Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# Battle of the Whispering Wood                          Robb Stark, Brynden Tully
#
#                                                               defender_commander  \
# name
# Battle of the Golden Tooth                                  Clement Piper, Vance
# Battle at the Mummer's Ford                                     Beric Dondarrion
# Battle of Riverrun                                 Edmure Tully, Tytos Blackwood
# Battle of the Green Fork       Tywin Lannister, Gregor Clegane, Kevan Lannist...
# Battle of the Whispering Wood                                    Jaime Lannister
#
#                                summer         location           region note
# name
# Battle of the Golden Tooth        1.0     Golden Tooth  The Westerlands  NaN
# Battle at the Mummer's Ford       1.0    Mummer's Ford   The Riverlands  NaN
# Battle of Riverrun                1.0         Riverrun   The Riverlands  NaN
# Battle of the Green Fork          1.0       Green Fork   The Riverlands  NaN
# Battle of the Whispering Wood     1.0  Whispering Wood   The Riverlands  NaN
#
# [5 rows x 24 columns]

# %%
large_battle_mask = battles['attacker_size'] + battles['defender_size'] > 10000
large_battles = battles.loc[large_battle_mask, ['attacker_size', 'defender_size']]
large_battles.shape
# Out:
# (10, 2)

# %%
large_battles
# Out:
#                             attacker_size  defender_size
# name
# Battle of the Golden Tooth        15000.0         4000.0
# Battle of Riverrun                15000.0        10000.0
# Battle of the Green Fork          18000.0        20000.0
# Battle of the Camps                6000.0        12625.0
# Battle of Oxcross                  6000.0        10000.0
# Siege of Storm's End               5000.0        20000.0
# Battle of the Fords               20000.0        10000.0
# Battle of the Blackwater          21000.0         7250.0
# Battle of Castle Black           100000.0         1240.0
# Siege of Winterfell                5000.0         8000.0

# %%
ax2 = large_battles.plot(kind='barh', stacked=True, fontsize=8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
large_battles['attacker_pcts'] = large_battles['attacker_size'] / (large_battles['attacker_size'] + large_battles['defender_size'])
large_battles['defender_pcts'] = large_battles['defender_size'] / (large_battles['attacker_size'] + large_battles['defender_size'])
large_battles
# Out:
#                             attacker_size  defender_size  attacker_pcts  \
# name
# Battle of the Golden Tooth        15000.0         4000.0       0.789474
# Battle of Riverrun                15000.0        10000.0       0.600000
# Battle of the Green Fork          18000.0        20000.0       0.473684
# Battle of the Camps                6000.0        12625.0       0.322148
# Battle of Oxcross                  6000.0        10000.0       0.375000
# Siege of Storm's End               5000.0        20000.0       0.200000
# Battle of the Fords               20000.0        10000.0       0.666667
# Battle of the Blackwater          21000.0         7250.0       0.743363
# Battle of Castle Black           100000.0         1240.0       0.987752
# Siege of Winterfell                5000.0         8000.0       0.384615
#
#                             defender_pcts
# name
# Battle of the Golden Tooth       0.210526
# Battle of Riverrun               0.400000
# Battle of the Green Fork         0.526316
# Battle of the Camps              0.677852
# Battle of Oxcross                0.625000
# Siege of Storm's End             0.800000
# Battle of the Fords              0.333333
# Battle of the Blackwater         0.256637
# Battle of Castle Black           0.012248
# Siege of Winterfell              0.615385

# %%
ax3 = large_battles[['attacker_pcts', 'defender_pcts']].plot(kind='barh', stacked=True, fontsize=8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
battles
# Out:
#                                                     year  battle_number  \
# name
# Battle of the Golden Tooth                           298              1
# Battle at the Mummer's Ford                          298              2
# Battle of Riverrun                                   298              3
# Battle of the Green Fork                             298              4
# Battle of the Whispering Wood                        298              5
# Battle of the Camps                                  298              6
# Sack of Darry                                        298              7
# Battle of Moat Cailin                                299              8
# Battle of Deepwood Motte                             299              9
# Battle of the Stony Shore                            299             10
# Battle of Torrhen's Square                           299             11
# Battle of Winterfell                                 299             12
# Sack of Torrhen's Square                             299             13
# Sack of Winterfell                                   299             14
# Battle of Oxcross                                    299             15
# Siege of Storm's End                                 299             16
# Battle of the Fords                                  299             17
# Sack of Harrenhal                                    299             18
# Battle of the Crag                                   299             19
# Battle of the Blackwater                             299             20
# Siege of Darry                                       299             21
# Battle of Duskendale                                 299             22
# Battle of the Burning Septry                         299             23
# Battle of the Ruby Ford                              299             24
# Retaking of Harrenhal                                299             25
# The Red Wedding                                      299             26
# Siege of Seagard                                     299             27
# Battle of Castle Black                               300             28
# Fall of Moat Cailin                                  300             29
# Sack of Saltpans                                     300             30
# Retaking of Deepwood Motte                           300             31
# Battle of the Shield Islands                         300             32
# Invasion of Ryamsport, Vinetown, and Starfish H...   300             33
# Second Seige of Storm's End                          300             34
# Siege of Dragonstone                                 300             35
# Siege of Riverrun                                    300             36
# Siege of Raventree                                   300             37
# Siege of Winterfell                                  300             38
#
#                                                                attacker_king  \
# name
# Battle of the Golden Tooth                          Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford                         Joffrey/Tommen Baratheon
# Battle of Riverrun                                  Joffrey/Tommen Baratheon
# Battle of the Green Fork                                          Robb Stark
# Battle of the Whispering Wood                                     Robb Stark
# Battle of the Camps                                               Robb Stark
# Sack of Darry                                       Joffrey/Tommen Baratheon
# Battle of Moat Cailin                                    Balon/Euron Greyjoy
# Battle of the Shield Islands                        Joffrey/Tommen Baratheon
# Invasion of Ryamsport, Vinetown, and Starfish H...  Joffrey/Tommen Baratheon
# Second Seige of Storm's End                                Stannis Baratheon
# Siege of Dragonstone                                       Stannis Baratheon
# Siege of Riverrun                                                 Robb Stark
# Siege of Raventree                                                Robb Stark
# Siege of Winterfell                                 Joffrey/Tommen Baratheon
#
#                                                                      attacker_1  \
# name
# Battle of the Golden Tooth                                            Lannister
# Battle at the Mummer's Ford                                           Lannister
# Battle of Riverrun                                                    Lannister
# Battle of the Green Fork                                                  Stark
# Battle of the Whispering Wood                                             Stark
# Battle of the Camps                                                       Stark
# Sack of Darry                                                         Lannister
# Battle of Moat Cailin                                                   Greyjoy
# Battle of Deepwood Motte                                                Greyjoy
# Battle of the Stony Shore                                               Greyjoy
# Battle of Torrhen's Square                                                Stark
# Battle of Winterfell                                                    Greyjoy
# Sack of Torrhen's Square                                                Greyjoy
# Sack of Winterfell                                                       Bolton
# Battle of Oxcross                                                         Stark
# Siege of Storm's End                                                  Baratheon
# Battle of the Fords                                                   Lannister
# Sack of Harrenhal                                                         Stark
# Battle of the Crag                                                        Stark
# Battle of the Blackwater                                              Baratheon
# Siege of Darry                                                            Darry
# Battle of Duskendale                                                      Stark
# Battle of the Burning Septry                        Brotherhood without Banners
# Battle of the Ruby Ford                                               Lannister
# Retaking of Harrenhal                                                 Lannister
# The Red Wedding                                                            Frey
# Siege of Seagard                                                           Frey
# Battle of Castle Black                                                Free folk
# Fall of Moat Cailin                                                      Bolton
# Sack of Saltpans                                               Brave Companions
# Retaking of Deepwood Motte                                            Baratheon
# Battle of the Shield Islands                                            Greyjoy
# Invasion of Ryamsport, Vinetown, and Starfish H...                      Greyjoy
# Second Seige of Storm's End                                           Baratheon
# Siege of Dragonstone                                                  Baratheon
# Siege of Riverrun                                                     Lannister
# Siege of Raventree                                                      Bracken
# Siege of Winterfell                                                   Baratheon
#
#                                                    attacker_2 attacker_3  \
# name
# Battle of the Golden Tooth                                NaN        NaN
# Battle at the Mummer's Ford                               NaN        NaN
# Battle of Riverrun                                        NaN        NaN
# Battle of the Green Fork                                  NaN        NaN
# Battle of the Whispering Wood                           Tully        NaN
# Battle of the Camps                                     Tully        NaN
# Sack of Darry                                             NaN        NaN
# Battle of Moat Cailin                                     NaN        NaN
# Battle of Deepwood Motte                                  NaN        NaN
# Battle of the Stony Shore                                 NaN        NaN
# Battle of Torrhen's Square                                NaN        NaN
# Battle of Winterfell                                      NaN        NaN
# Sack of Torrhen's Square                                  NaN        NaN
# Sack of Winterfell                                    Greyjoy        NaN
# Battle of Oxcross                                       Tully        NaN
# Siege of Storm's End                                      NaN        NaN
# Battle of the Fords                                       NaN        NaN
# Sack of Harrenhal                                         NaN        NaN
# Battle of the Crag                                        NaN        NaN
# Battle of the Blackwater                                  NaN        NaN
# Siege of Darry                                            NaN        NaN
# Battle of Duskendale                                      NaN        NaN
# Battle of the Burning Septry                              NaN        NaN
# Battle of the Ruby Ford                                   NaN        NaN
# Retaking of Harrenhal                                     NaN        NaN
# The Red Wedding                                        Bolton        NaN
# Siege of Seagard                                          NaN        NaN
# Battle of Castle Black                                 Thenns     Giants
# Fall of Moat Cailin                                       NaN        NaN
# Sack of Saltpans                                          NaN        NaN
# Retaking of Deepwood Motte                           Karstark    Mormont
# Battle of the Shield Islands                              NaN        NaN
# Invasion of Ryamsport, Vinetown, and Starfish H...        NaN        NaN
# Second Seige of Storm's End                               NaN        NaN
# Siege of Dragonstone                                      NaN        NaN
# Siege of Riverrun                                        Frey        NaN
# Siege of Raventree                                  Lannister        NaN
# Siege of Winterfell                                  Karstark    Mormont
#
#                                                    attacker_4  \
# name
# Battle of the Golden Tooth                                NaN
# Battle at the Mummer's Ford                               NaN
# Battle of Riverrun                                        NaN
# Battle of the Green Fork                                  NaN
# Battle of the Whispering Wood                             NaN
# Battle of the Camps                                       NaN
# Sack of Darry                                             NaN
# Battle of Moat Cailin                                     NaN
# Battle of Deepwood Motte                                  NaN
# Battle of the Stony Shore                                 NaN
# Battle of Torrhen's Square                                NaN
# Battle of Winterfell                                      NaN
# Sack of Torrhen's Square                                  NaN
# Sack of Winterfell                                        NaN
# Battle of Oxcross                                         NaN
# Siege of Storm's End                                      NaN
# Battle of the Fords                                       NaN
# Sack of Harrenhal                                         NaN
# Battle of the Crag                                        NaN
# Battle of the Blackwater                                  NaN
# Siege of Darry                                            NaN
# Battle of Duskendale                                      NaN
# Battle of the Burning Septry                              NaN
# Battle of the Ruby Ford                                   NaN
# Retaking of Harrenhal                                     NaN
# The Red Wedding                                           NaN
# Siege of Seagard                                          NaN
# Battle of Castle Black                                    NaN
# Fall of Moat Cailin                                       NaN
# Sack of Saltpans                                          NaN
# Retaking of Deepwood Motte                             Glover
# Battle of the Shield Islands                              NaN
# Invasion of Ryamsport, Vinetown, and Starfish H...        NaN
# Second Seige of Storm's End                               NaN
# Siege of Dragonstone                                      NaN
# Siege of Riverrun                                         NaN
# Siege of Raventree                                        NaN
# Siege of Winterfell                                    Glover
#
#                                                           defender_1  \
# name
# Battle of the Golden Tooth                                     Tully
# Battle at the Mummer's Ford                                Baratheon
# Battle of Riverrun                                             Tully
# Battle of the Green Fork                                   Lannister
# Battle of the Whispering Wood                              Lannister
# Battle of the Camps                                        Lannister
# Sack of Darry                                                  Darry
# Battle of Moat Cailin                                          Stark
# Battle of Deepwood Motte                                       Stark
# Battle of the Stony Shore                                      Stark
# Battle of Torrhen's Square                                   Greyjoy
# Battle of Winterfell                                           Stark
# Sack of Torrhen's Square                                       Stark
# Sack of Winterfell                                             Stark
# Battle of Oxcross                                          Lannister
# Siege of Storm's End                                       Baratheon
# Battle of the Fords                                            Tully
# Sack of Harrenhal                                          Lannister
# Battle of the Crag                                         Lannister
# Battle of the Blackwater                                   Lannister
# Siege of Darry                                             Lannister
# Battle of Duskendale                                       Lannister
# Battle of the Burning Septry                        Brave Companions
# Battle of the Ruby Ford                                        Stark
# Retaking of Harrenhal                               Brave Companions
# The Red Wedding                                                Stark
# Siege of Seagard                                           Mallister
# Battle of Castle Black                                 Night's Watch
# Fall of Moat Cailin                                          Greyjoy
# Sack of Saltpans                                                 NaN
# Retaking of Deepwood Motte                                   Greyjoy
# Battle of the Shield Islands                                  Tyrell
# Invasion of Ryamsport, Vinetown, and Starfish H...            Tyrell
# Second Seige of Storm's End                                Baratheon
# Siege of Dragonstone                                       Baratheon
# Siege of Riverrun                                              Tully
# Siege of Raventree                                         Blackwood
# Siege of Winterfell                                           Bolton
#
#                                                    defender_2  ...  \
# name                                                           ...
# Battle of the Golden Tooth                                NaN  ...
# Battle at the Mummer's Ford                               NaN  ...
# Battle of Riverrun                                        NaN  ...
# Battle of the Green Fork                                  NaN  ...
# Battle of the Whispering Wood                             NaN  ...
# Battle of the Camps                                       NaN  ...
# Sack of Darry                                             NaN  ...
# Battle of Moat Cailin                                     NaN  ...
# Battle of Deepwood Motte                                  NaN  ...
# Battle of the Stony Shore                                 NaN  ...
# Battle of Torrhen's Square                                NaN  ...
# Battle of Winterfell                                      NaN  ...
# Sack of Torrhen's Square                                  NaN  ...
# Sack of Winterfell                                        NaN  ...
# Battle of Oxcross                                         NaN  ...
# Siege of Storm's End                                      NaN  ...
# Battle of the Fords                                       NaN  ...
# Sack of Harrenhal                                         NaN  ...
# Battle of the Crag                                        NaN  ...
# Battle of the Blackwater                                  NaN  ...
# Siege of Darry                                            NaN  ...
# Battle of Duskendale                                      NaN  ...
# Battle of the Burning Septry                              NaN  ...
# Battle of the Ruby Ford                                   NaN  ...
# Retaking of Harrenhal                                     NaN  ...
# The Red Wedding                                           NaN  ...
# Siege of Seagard                                          NaN  ...
# Battle of Castle Black                              Baratheon  ...
# Fall of Moat Cailin                                       NaN  ...
# Sack of Saltpans                                          NaN  ...
# Retaking of Deepwood Motte                                NaN  ...
# Battle of the Shield Islands                              NaN  ...
# Invasion of Ryamsport, Vinetown, and Starfish H...        NaN  ...
# Second Seige of Storm's End                               NaN  ...
# Siege of Dragonstone                                      NaN  ...
# Siege of Riverrun                                         NaN  ...
# Siege of Raventree                                        NaN  ...
# Siege of Winterfell                                      Frey  ...
#
#                                                     major_death  \
# name
# Battle of the Golden Tooth                                  1.0
# Battle at the Mummer's Ford                                 1.0
# Battle of Riverrun                                          0.0
# Battle of the Green Fork                                    1.0
# Battle of the Whispering Wood                               1.0
# Battle of the Camps                                         0.0
# Sack of Darry                                               0.0
# Battle of Moat Cailin                                       0.0
# Battle of Deepwood Motte                                    0.0
# Battle of the Stony Shore                                   0.0
# Battle of Torrhen's Square                                  0.0
# Battle of Winterfell                                        0.0
# Sack of Torrhen's Square                                    0.0
# Sack of Winterfell                                          1.0
# Battle of Oxcross                                           1.0
# Siege of Storm's End                                        1.0
# Battle of the Fords                                         0.0
# Sack of Harrenhal                                           1.0
# Battle of the Crag                                          0.0
# Battle of the Blackwater                                    1.0
# Siege of Darry                                              0.0
# Battle of Duskendale                                        1.0
# Battle of the Burning Septry                                0.0
# Battle of the Ruby Ford                                     0.0
# Retaking of Harrenhal                                       1.0
# The Red Wedding                                             1.0
# Siege of Seagard                                            0.0
# Battle of Castle Black                                      1.0
# Fall of Moat Cailin                                         0.0
# Siege of Winterfell                                                                               NaN
#
# [38 rows x 24 columns]

# %%
col_names = battles.columns[4:12]
col_names
# Out:
# Index(['attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4'],
#       dtype='object')

# %%
# 각 가문이 얼마나 전투에 참여했는지 보기위해 먼저 col_names를 가져왔다.
# 이에 대해서 unique 처리를 하려고하는데, 이때 NaN값이 있으면 오류가 발생하므로 이를 먼저 처리한다.
# NaN을 None이라는 문자열로 대체할 것
house_names = battles[col_names].fillna("None").values
house_names[:5]
# Out:
# array([['Lannister', 'None', 'None', 'None', 'Tully', 'None', 'None',
#         'None'],
#        ['Lannister', 'None', 'None', 'None', 'Baratheon', 'None', 'None',
#         'None'],
#        ['Lannister', 'None', 'None', 'None', 'Tully', 'None', 'None',
#         'None'],
#        ['Stark', 'None', 'None', 'None', 'Lannister', 'None', 'None',
#         'None'],
#        ['Stark', 'Tully', 'None', 'None', 'Lannister', 'None', 'None',
#         'None']], dtype=object)

# %%
house_names = np.unique(house_names)
house_names
# Out:
# array(['Baratheon', 'Blackwood', 'Bolton', 'Bracken', 'Brave Companions',
#        'Brotherhood without Banners', 'Darry', 'Free folk', 'Frey',
#        'Giants', 'Glover', 'Greyjoy', 'Karstark', 'Lannister',
#        'Mallister', 'Mormont', "Night's Watch", 'None', 'Stark', 'Thenns',
#        'Tully', 'Tyrell'], dtype=object)

# %%
house_names = house_names[house_names != 'None']
house_names
# Out:
# array(['Baratheon', 'Blackwood', 'Bolton', 'Bracken', 'Brave Companions',
#        'Brotherhood without Banners', 'Darry', 'Free folk', 'Frey',
#        'Giants', 'Glover', 'Greyjoy', 'Karstark', 'Lannister',
#        'Mallister', 'Mormont', "Night's Watch", 'Stark', 'Thenns',
#        'Tully', 'Tyrell'], dtype=object)

# %%
houses_to_battle_counts = pd.Series(0, index=house_names)
houses_to_battle_counts
# Out:
# Baratheon                      0
# Blackwood                      0
# Bolton                         0
# Bracken                        0
# Brave Companions               0
# Brotherhood without Banners    0
# Darry                          0
# Free folk                      0
# Frey                           0
# Giants                         0
# Glover                         0
# Greyjoy                        0
# Karstark                       0
# Lannister                      0
# Mallister                      0
# Mormont                        0
# Night's Watch                  0
# Stark                          0
# Thenns                         0
# Tully                          0
# Tyrell                         0
# dtype: int64

# %%
for col in col_names:
    houses_to_battle_counts = houses_to_battle_counts.add(battles[col].value_counts(), fill_value = 0)
houses_to_battle_counts
# Out:
# Baratheon                      11.0
# Blackwood                       1.0
# Bolton                          4.0
# Bracken                         1.0
# Brave Companions                3.0
# Brotherhood without Banners     1.0
# Darry                           2.0
# Free folk                       1.0
# Frey                            4.0
# Giants                          1.0
# Glover                          2.0
# Greyjoy                        11.0
# Karstark                        2.0
# Lannister                      18.0
# Mallister                       1.0
# Mormont                         2.0
# Night's Watch                   1.0
# Stark                          16.0
# Thenns                          1.0
# Tully                           7.0
# Tyrell                          2.0
# dtype: float64

# %%
plt.figure()
ax4 = houses_to_battle_counts.hist(bins=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
